# %% [markdown]
# ## **Introducciòn a uso de Datasets**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Debemos utilizar Panda (como pd) para leer un archivo desde una URL
# La última línea escribe el contenido de la variable

# %%
df = pd.read_csv('https://www.datos.gov.co/api/views/ynam-yc42/rows.csv?accessType=DOWNLOAD')
# df = pd.read_csv('https://www.datos.gov.co/api/views/2x55-9wxm/rows.csv?accessType=DOWNLOAD')
df
# Out:
# <ipython-input-2-bbdd6d9fd7b1>:1: DtypeWarning: Columns (76,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://www.datos.gov.co/api/views/ynam-yc42/rows.csv?accessType=DOWNLOAD')
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                      TI          COLOMBIA           M
# 1                      TI          COLOMBIA           M
# 2                      TI          COLOMBIA           M
# 3                      TI          COLOMBIA           M
# 4                      TI          COLOMBIA           M
# ...                   ...               ...         ...
# 546207                 CC          COLOMBIA           M
# 546208                 TI          COLOMBIA           M
# 546209                 TI          COLOMBIA           M
# 546210                 TI          COLOMBIA           M
# 546211                 TI          COLOMBIA           M
#
# ...

# %%
# Con head puedo pedir que me muestre solo el encabezado
# enviando cero como parámetro. Por defecto me muestra 5 filas
df.head(15)
# Out:
#    ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                  TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                  TI          COLOMBIA           M  06/28/2003 12:00:00 AM
# 2                  TI          COLOMBIA           M  06/02/2001 12:00:00 AM
# 3                  TI          COLOMBIA           M  04/26/2002 12:00:00 AM
# 4                  TI          COLOMBIA           M  02/05/2002 12:00:00 AM
# 5                  CC          COLOMBIA           M  04/08/1999 12:00:00 AM
# 6                  TI          COLOMBIA           M  11/09/2002 12:00:00 AM
# 7                  TI          COLOMBIA           M  08/14/2002 12:00:00 AM
# 8                  TI          COLOMBIA           M  04/14/2002 12:00:00 AM
# 9                  TI          COLOMBIA           M  12/07/2002 12:00:00 AM
# 10                 TI          COLOMBIA           M  01/07/2001 12:00:00 AM
# ...

# %% [markdown]
# Escogencia de solo un subconjunto de columnas

# %%
df1 = df[['ESTU_TIPODOCUMENTO', 'ESTU_GENERO', 'ESTU_FECHANACIMIENTO', 'ESTU_DEPTO_RESIDE', 'ESTU_MCPIO_RESIDE', 'PUNT_GLOBAL']]
df1
# Out:
#        ESTU_TIPODOCUMENTO ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                      TI           M  02/18/2002 12:00:00 AM
# 1                      TI           M  06/28/2003 12:00:00 AM
# 2                      TI           M  06/02/2001 12:00:00 AM
# 3                      TI           M  04/26/2002 12:00:00 AM
# 4                      TI           M  02/05/2002 12:00:00 AM
# ...                   ...         ...                     ...
# 546207                 CC           M  02/25/1999 12:00:00 AM
# 546208                 TI           M  10/14/2002 12:00:00 AM
# 546209                 TI           M  11/22/2002 12:00:00 AM
# 546210                 TI           M  11/10/2002 12:00:00 AM
# 546211                 TI           M  06/02/2002 12:00:00 AM
#
#        ESTU_DEPTO_RESIDE    ESTU_MCPIO_RESIDE  PUNT_GLOBAL
# 0              MAGDALENA            SANTA ANA          208
# 1                 BOGOTÁ          BOGOTÁ D.C.          299
# ...

# %%
# Este comando cambia los nombres de las columnas
df1.columns = ['TIPDOC', 'GENERO', 'FECHANACIMIENTO', 'DEPTO_RESIDE', 'MCPIO_RESIDE', 'PUNT_GLOBAL']
df1
# Out:
#        TIPDOC GENERO         FECHANACIMIENTO DEPTO_RESIDE  \
# 0          TI      M  02/18/2002 12:00:00 AM    MAGDALENA
# 1          TI      M  06/28/2003 12:00:00 AM       BOGOTÁ
# 2          TI      M  06/02/2001 12:00:00 AM      BOLIVAR
# 3          TI      M  04/26/2002 12:00:00 AM       BOGOTÁ
# 4          TI      M  02/05/2002 12:00:00 AM       BOGOTÁ
# ...       ...    ...                     ...          ...
# 546207     CC      M  02/25/1999 12:00:00 AM    ANTIOQUIA
# 546208     TI      M  10/14/2002 12:00:00 AM       BOGOTÁ
# 546209     TI      M  11/22/2002 12:00:00 AM       ARAUCA
# 546210     TI      M  11/10/2002 12:00:00 AM    SANTANDER
# 546211     TI      M  06/02/2002 12:00:00 AM       BOGOTÁ
#
#                MCPIO_RESIDE  PUNT_GLOBAL
# 0                 SANTA ANA          208
# 1               BOGOTÁ D.C.          299
# 2       CARTAGENA DE INDIAS          299
# 3               BOGOTÁ D.C.          309
# 4               BOGOTÁ D.C.          288
# ...

# %%
#df1['PUNT_GLOBAL']
text_dict = {'size':16,'color':'blue'};
plt.figure(figsize=(8,6));
plt.hist(df1['PUNT_GLOBAL'],color='red');
plt.xlabel('Puntaje Global',fontdict=text_dict);
